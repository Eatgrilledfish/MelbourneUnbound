# %%
import gtfs_realtime_pb2

# Load the GTFS Realtime data
feed = gtfs_realtime_pb2.FeedMessage()
with open("trip_updates.pb", "rb") as file:
    feed.ParseFromString(file.read())

# Access and print vehicle information within TripUpdates
for entity in feed.entity:
    if entity.HasField('trip_update'):
        # Check if vehicle information is available
        if entity.trip_update.trip.HasField('vehicle'):
            vehicle = entity.trip_update.trip.vehicle
            print(f"Trip ID: {entity.trip_update.trip.trip_id} - Vehicle Information:")
            print(f"  Vehicle ID: {vehicle.id}")
            print(f"  Vehicle Label: {vehicle.label}")
            print(f"  Vehicle License Plate: {vehicle.license_plate}")
        else:
            print(f"Trip ID: {entity.trip_update.trip.trip_id} - No vehicle information available.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 12
#       9 for entity in feed.entity:
#      10     if entity.HasField('trip_update'):
#      11         # Check if vehicle information is available
# ---> 12         if entity.trip_update.trip.HasField('vehicle'):
#      13             vehicle = entity.trip_update.trip.vehicle
#      14             print(f"Trip ID: {entity.trip_update.trip.trip_id} - Vehicle Information:")
#
# ValueError: Protocol message TripDescriptor has no "vehicle" field.

# %%
import gtfs_realtime_pb2
import requests

def parse_vehicle_data(data):
    feed = gtfs_realtime_pb2.FeedMessage()
    feed.ParseFromString(data)

    vehicles_info = []
    for entity in feed.entity:
        if entity.HasField('vehicle'):
            vehicle = entity.vehicle
            trip = vehicle.trip
            position = vehicle.position
            vehicle_details = vehicle.vehicle

            vehicle_info = {
                "Vehicle ID": vehicle_details.id,
                "Vehicle Label": vehicle_details.label,
                "Trip ID": trip.trip_id,
                "Start Time": trip.start_time,
                "Start Date": trip.start_date,
                "Schedule Relationship": trip.schedule_relationship,
                "Latitude": position.latitude,
                "Longitude": position.longitude,
                "Timestamp": vehicle.timestamp
            }
            vehicles_info.append(vehicle_info)
    
    return vehicles_info

# 获取数据
url = "https://data-exchange-api.vicroads.vic.gov.au/opendata/gtfsr/v1/tram/vehicleposition"
headers = {
    "Ocp-Apim-Subscription-Key": "af02fa9cf4764385ad592b462db4ec8e"
}
response = requests.get(url, headers=headers)

if response.status_code == 200:
    vehicles_info = parse_vehicle_data(response.content)
    for info in vehicles_info:
        print(info)
else:
    print("Failed to fetch data:", response.status_code)
# Out:
# {'Vehicle ID': '6013.499.T0.3-86-mjp-1.6.R', 'Vehicle Label': 'Bombardier Flexity Swift (E1.6013)', 'Trip ID': '499.T0.3-86-mjp-1.6.R', 'Start Time': '14:58:00', 'Start Date': '20240506', 'Schedule Relationship': 0, 'Latitude': -37.81333541870117, 'Longitude': 144.94158935546875, 'Timestamp': 1714977029}
# {'Vehicle ID': '6030.192.T0.3-86-mjp-1.3.H', 'Vehicle Label': 'Bombardier Flexity Swift (E1.6030)', 'Trip ID': '192.T0.3-86-mjp-1.3.H', 'Start Time': '14:53:00', 'Start Date': '20240506', 'Schedule Relationship': 0, 'Latitude': -37.683250427246094, 'Longitude': 145.06881713867188, 'Timestamp': 1714977029}
# {'Vehicle ID': '3510.351.T0.3-16-mjp-1.10.R', 'Vehicle Label': 'Siemens Combino (D1.3510)', 'Trip ID': '351.T0.3-16-mjp-1.10.R', 'Start Time': '14:50:00', 'Start Date': '20240506', 'Schedule Relationship': 0, 'Latitude': -37.80455017089844, 'Longitude': 144.9632568359375, 'Timestamp': 1714976990}
# ...

# %%
import requests
import gtfs_realtime_pb2

url = "https://data-exchange-api.vicroads.vic.gov.au/opendata/gtfsr/v1/tram/vehicleposition"
headers = {
    "Ocp-Apim-Subscription-Key": "af02fa9cf4764385ad592b462db4ec8e"
}
response = requests.get(url, headers=headers)

if response.status_code == 200:
    feed = gtfs_realtime_pb2.FeedMessage()
    feed.ParseFromString(response.content)
    for entity in feed.entity:
        print("this is entity",entity)
else:
    print("Failed to fetch data:", response.status_code)
# Out:
# this is entity id: "VP.368.T0.3-75-mjp-1.6.R"
# vehicle {
#   trip {
#     trip_id: "368.T0.3-75-mjp-1.6.R"
#     start_time: "15:54:00"
#     start_date: "20240506"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "2101.368.T0.3-75-mjp-1.6.R"
#     label: "Comeng (B2.2101)"
#   }
#   position {
#     latitude: -37.814579
#     longitude: 144.944809
#   }
#   timestamp: 1714979900
# }
#
# this is entity id: "VP.542.T0.3-86-mjp-1.6.R"
# vehicle {
#   trip {
#     trip_id: "542.T0.3-86-mjp-1.6.R"
#     start_time: "15:43:00"
#     start_date: "20240506"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "6024.542.T0.3-86-mjp-1.6.R"
#     label: "Bombardier Flexity Swift (E1.6024)"
#   }
#   position {
#     latitude: -37.8133736
#     longitude: 144.941483
#   }
#   timestamp: 1714979811
# }
#
# this is entity id: "VP.544.T0.3-86-mjp-1.6.R"
# vehicle {
#   trip {
#     trip_id: "544.T0.3-86-mjp-1.6.R"
#     start_time: "15:49:00"
# ...

# %%
import gtfs_realtime_pb2
import requests

def parse_vehicle_data_for_trip_id(data, trip_id_to_find):
    feed = gtfs_realtime_pb2.FeedMessage()
    feed.ParseFromString(data)

    inaccessible_models = ['Z1', 'Z3', 'A1', 'A2']
    for entity in feed.entity:
        if entity.HasField('vehicle'):
            vehicle = entity.vehicle
            trip = vehicle.trip
            if trip.trip_id == trip_id_to_find:  # Check if the current trip ID matches the desired trip ID
                position = vehicle.position
                vehicle_details = vehicle.vehicle
                # Check if the vehicle label contains any of the specified inaccessible models
                accessible = 0 if any(model in vehicle_details.label for model in inaccessible_models) else 1
                vehicle_info = {
                    "Vehicle ID": vehicle_details.id,
                    "Vehicle Label": vehicle_details.label,
                    "Accessible": accessible  # Add accessibility info
                }
                return vehicle_info  # Return the found vehicle info immediately
    return None  # Return None if no vehicle matches the specified trip ID

# Get data
url = "https://data-exchange-api.vicroads.vic.gov.au/opendata/gtfsr/v1/tram/vehicleposition"
headers = {
    "Ocp-Apim-Subscription-Key": "af02fa9cf4764385ad592b462db4ec8e"
}
response = requests.get(url, headers=headers)

if response.status_code == 200:
    specific_trip_id = "45.T0.3-86-mjp-4.3.H"  # The trip ID you are interested in
    vehicle_info = parse_vehicle_data_for_trip_id(response.content, specific_trip_id)
    if vehicle_info:
        print(vehicle_info)
    else:
        print(f"No vehicle found for trip ID: {specific_trip_id}")
else:
    print("Failed to fetch data:", response.status_code)
# Out:
# {'Vehicle ID': '6017.45.T0.3-86-mjp-4.3.H', 'Vehicle Label': 'Bombardier Flexity Swift (E1.6017)', 'Accessible': 1}

# %%
import gtfs_realtime_pb2

# Load the GTFS Realtime data
feed = gtfs_realtime_pb2.FeedMessage()
with open("vehicle_positions.pb", "rb") as file:
    feed.ParseFromString(file.read())

# Iterate over each entity in the feed and only process the first one
for entity in feed.entity:
    vehicle = entity
        # Check if a VehicleDescriptor is available
    print(vehicle)  # Print the first vehicle descriptor
      # Exit the loop after the first vehicle is processed
# Out:
# id: "VP.239.T0.3-86-mjp-1.3.H"
# vehicle {
#   trip {
#     trip_id: "239.T0.3-86-mjp-1.3.H"
#     start_time: "12:45:00"
#     start_date: "20240412"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "6037.239.T0.3-86-mjp-1.3.H"
#     label: "Bombardier Flexity Swift (E1.6037)"
#   }
#   position {
#     latitude: -37.6851463
#     longitude: 145.068466
#   }
#   timestamp: 1712895593
# }
#
# id: "VP.128.T0.3-16-mjp-1.6.H"
# vehicle {
#   trip {
#     trip_id: "128.T0.3-16-mjp-1.6.H"
#     start_time: "12:54:00"
#     start_date: "20240412"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "3521.128.T0.3-16-mjp-1.6.H"
#     label: "Siemens Combino (D1.3521)"
#   }
#   position {
#     latitude: -37.8122711
#     longitude: 145.037277
#   }
#   timestamp: 1712896000
# }
#
# id: "VP.240.T0.3-86-mjp-1.3.H"
# vehicle {
#   trip {
#     trip_id: "240.T0.3-86-mjp-1.3.H"
#     start_time: "12:53:00"
#     start_date: "20240412"
# ...

# %%
import gtfs_realtime_pb2

# Load the GTFS Realtime data
feed = gtfs_realtime_pb2.FeedMessage()
with open("trip_updates.pb", "rb") as file:
    feed.ParseFromString(file.read())

# Iterate over each entity in the feed and only process the first one
for entity in feed.entity:
    trip = entity
        # Check if a VehicleDescriptor is available
    print(trip)  # Print the first vehicle descriptor
    break  # Exit the loop after the first vehicle is processed
# Out:
# id: "TU.235.T0.3-86-mjp-1.3.H"
# trip_update {
#   trip {
#     trip_id: "235.T0.3-86-mjp-1.3.H"
#     start_time: "12:13:00"
#     start_date: "20240412"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "6034"
#   }
#   stop_time_update {
#     stop_sequence: 61
#     stop_id: "4182"
#     arrival {
#       delay: 1194
#       time: 1712893794
#     }
#     departure {
#       delay: 1194
#       time: 1712893794
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 62
#     stop_id: "4181"
#     arrival {
#       delay: 1194
#       time: 1712893854
#     }
#     departure {
#       delay: 1194
#       time: 1712893854
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 63
#     stop_id: "4180"
#     arrival {
#       delay: 1194
#       time: 1712893974
#     }
#     departure {
#       delay: 1194
#       time: 1712893974
#     }
#     schedule_relationship: SCHEDULED
# ...

# %%
import gtfs_realtime_pb2

# Load the GTFS Realtime data
feed = gtfs_realtime_pb2.FeedMessage()
with open("service_alerts.pb", "rb") as file:
    feed.ParseFromString(file.read())

# Iterate over each entity in the feed and only process the first one
for entity in feed.entity:
    trip = entity
        # Check if a VehicleDescriptor is available
    print(trip)  # Print the first vehicle descriptor
    break  # Exit the loop after the first vehicle is processed
# Out:
# id: "SA.tt-d6f31c6699b7c2bb2d94a2d6dae3d9d8b5aecc2b"
# alert {
#   informed_entity {
#     trip {
#       trip_id: "1.T0.3-67-mjp-1.1.H"
#     }
#   }
#   informed_entity {
#     trip {
#       trip_id: "229.T0.3-67-mjp-1.5.R"
#     }
#   }
#   informed_entity {
#     trip {
#       trip_id: "2.T0.3-67-mjp-1.1.H"
#     }
#   }
#   informed_entity {
#     trip {
#       trip_id: "3.T0.3-67-mjp-1.1.H"
#     }
#   }
#   informed_entity {
#     trip {
#       trip_id: "232.T0.3-67-mjp-1.5.R"
#     }
#   }
#   informed_entity {
#     trip {
#       trip_id: "4.T0.3-67-mjp-1.1.H"
#     }
#   }
#   informed_entity {
#     trip {
#       trip_id: "234.T0.3-67-mjp-1.5.R"
#     }
#   }
#   informed_entity {
#     trip {
#       trip_id: "9.T0.3-67-mjp-1.1.H"
#     }
#   }
#   informed_entity {
#     trip {
#       trip_id: "236.T0.3-67-mjp-1.5.R"
#     }
#   }
#   informed_entity {
#     trip {
#       trip_id: "239.T0.3-67-mjp-1.5.R"
#     }
#   }
#   informed_entity {
#     trip {
# ...

# %%
# this one working


from hashlib import sha1
import hmac
import binascii

def getUrl(request):
    devId = 3002823  # Your developer ID
    key = '23301ed1-37b4-4eea-a384-43d667411ee9'  # Your developer key

    # Append devId to the request query
    request = request + ('&' if ('?' in request) else '?')
    raw = request + 'devid={0}'.format(devId)

    # Calculate HMAC-SHA1 signature
    hashed = hmac.new(key.encode(), raw.encode(), sha1)
    signature = hashed.hexdigest()

    # Return the complete URL with signature
    return 'https://timetableapi.ptv.vic.gov.au' + raw + '&signature={1}'.format(devId, signature)

# Example usage
print(getUrl('/v3/runs/2399?expand=All'))
# Out:
# https://timetableapi.ptv.vic.gov.au/v3/runs/2399?expand=All&devid=3002823&signature=814068fb69f2791b5f5baffd2415d46de2102f12

# %%
import psycopg2

def query_database():
    # 连接数据库的参数
    conn_params = {
        'host': '3.25.115.34',
        'port': '5432',
        'database': 'Static_data',
        'user': 'postgres',
        'password': 'root'  # 请替换为你的数据库密码
    }
    
    # 创建一个连接
    try:
        conn = psycopg2.connect(**conn_params)
        print("连接数据库成功")
    except Exception as e:
        print("连接失败:", e)
        return

    # 创建一个游标对象，并执行SQL查询
    try:
        with conn.cursor() as cur:
            # 执行查询
            cur.execute("SELECT * FROM public.bar_restaurant_data LIMIT 100")
            
            # 获取并打印查询结果
            results = cur.fetchall()
            for row in results:
                print(row)
    except Exception as e:
        print("查询失败:", e)
    finally:
        conn.close()  # 关闭连接

if __name__ == "__main__":
    query_database()
# Out:
# 连接数据库成功
# (2018, 589462, None, '38-46 Sabre Drive PORT MELBOURNE 3207', 'Sabre Cafe', -37.8279766213, 144.90633574660376, 0.0, 'Not determined or not applicable', 'Configuration of entrance does not fit into any of the other categories')
# (2010, 589462, None, '38-46 Sabre Drive FISHERMANS BEND 3207', 'Sabre Cafe', -37.8279766213, 144.90633574660376, 0.0, 'Not determined or not applicable', 'Configuration of entrance does not fit into any of the other categories')
# (2013, 589462, None, '38-46 Sabre Drive FISHERMANS BEND 3207', 'Sabre Cafe', -37.8279766213, 144.90633574660376, 0.0, 'Not determined or not applicable', 'Configuration of entrance does not fit into any of the other categories')
# (2014, 589462, None, '38-46 Sabre Drive FISHERMANS BEND 3207', 'Sabre Cafe', -37.8279766213, 144.90633574660376, 0.0, 'Not determined or not applicable', 'Configuration of entrance does not fit into any of the other categories')
# ...

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('/Users/jianqiao/Downloads/filtered_merged_data.csv')

# 确保 Censor_year 列的数据类型是数值型
df['Census_year'] = pd.to_numeric(df['Census_year'], errors='coerce')

# 按照 Property_ID 分组，然后找到每个组内 Censor_year 最大的记录
result_df = df.loc[df.groupby('Property_ID')['Census_year'].idxmax()]

# 保存结果到新的 CSV 文件
result_df.to_csv('filtered_data.csv', index=False)

# 打印输出查看
print(result_df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 10
#       7 df['Census_year'] = pd.to_numeric(df['Census_year'], errors='coerce')
#       9 # 按照 Property_ID 分组，然后找到每个组内 Censor_year 最大的记录
# ---> 10 result_df = df.loc[df.groupby('Property_ID')['Census_year'].idxmax()]
#      12 # 保存结果到新的 CSV 文件
#      13 result_df.to_csv('filtered_data.csv', index=False)
#
# File ~/miniconda3/envs/g13/lib/python3.9/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniconda3/envs/g13/lib/python3.9/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
# ...

# %%
df.head()
# Out:
#    Census_year  Property_ID Building_name  \
# 0       2018.0       589462           NaN
# 1       2010.0       589462           NaN
# 2       2013.0       589462           NaN
# 3       2014.0       589462           NaN
# 4       2022.0       589462           NaN
#
#                               Street_address Trading_name   Latitude  \
# 0      38-46 Sabre Drive PORT MELBOURNE 3207   Sabre Cafe -37.827977
# 1     38-46 Sabre Drive FISHERMANS BEND 3207   Sabre Cafe -37.827977
# 2     38-46 Sabre Drive FISHERMANS BEND 3207   Sabre Cafe -37.827977
# 3     38-46 Sabre Drive FISHERMANS BEND 3207   Sabre Cafe -37.827977
# 4  38-46 Sabre Drive PORT MELBOURNE VIC 3207   Sabre Cafe -37.827977
#
#     Longitude  Accessibility_rating                Accessibility_type  \
# 0  144.906336                   0.0  Not determined or not applicable
# 1  144.906336                   0.0  Not determined or not applicable
# 2  144.906336                   0.0  Not determined or not applicable
# ...

# %%
import requests
import psycopg2
import os

def download_image(image_url, local_filename, save_directory):
    # 确保存储目录存在
    if not os.path.exists(save_directory):
        os.makedirs(save_directory)

    # 完整文件路径
    full_path = os.path.join(save_directory, local_filename)
    
    # 下载并保存图片
    response = requests.get(image_url)
    if response.status_code == 200:
        with open(full_path, 'wb') as f:
            f.write(response.content)
        return local_filename  # 返回文件名
    return None


def query_google_places(restaurant_name, address, api_key):
    # 构建 Google Places API 请求以获取 Place ID
    search_url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={restaurant_name} {address}&inputtype=textquery&fields=place_id&key={api_key}"
    response = requests.get(search_url)
    search_results = response.json()

    if search_results['status'] == 'OK':
        place_id = search_results['candidates'][0]['place_id']
        
        # 使用 Place ID 获取详细信息
        details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=name,rating,photo,formatted_address,description&key={api_key}"
        response = requests.get(details_url)
        details = response.json()

        if details['status'] == 'OK':
            result = details['result']
            photo_reference = result['photos'][0]['photo_reference']
            photo_url = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photoreference={photo_reference}&key={api_key}"
            image_filename = download_image(photo_url, f"{place_id}.jpg")
            return {
                'rating': result.get('rating', 'No Rating'),
                'description': result.get('description', 'No Description'),
                'photo_filename': image_filename
            }
    return None
def update_database(conn_params, api_key, image_save_directory):
    # 建立数据库连接
    conn = psycopg2.connect(**conn_params)
    cur = conn.cursor()
    
    # 选择包含id的数据进行查询
    cur.execute("SELECT id, name, address FROM public.bar_restaurant_data")  # 现在包括 id
    rows = cur.fetchall()

    # 遍历每一行数据
    for row in rows:
        row_id, name, address = row  # 解包 id, name 和 address
        # 使用 name 和 address 查询 Google Places
        data = query_google_places(name, address, api_key)
        if data:
            # 下载图片并获取文件名
            image_filename = download_image(data['photo_url'], f"{name.replace(' ', '_')}_image.jpg", image_save_directory)
            
            if image_filename:
                # 使用 id 更新数据库
                cur.execute("UPDATE public.bar_restaurant_data SET rating = %s, description = %s, photo_filename = %s WHERE id = %s",
                            (data['rating'], data['description'], image_filename, row_id))
    # 提交事务并关闭连接
    conn.commit()
    conn.close()



if __name__ == "__main__":
    conn_params = {
        'host': '3.25.115.34',
        'port': '5432',
        'database': 'Static_data',
        'user': 'postgres',
        'password': 'root'  # 请替换为你的数据库密码
    }
    api_key = 'AIzaSyA4bcHQArQWH2Qxb47goCAhbstZX0WkUZk'
    update_database(conn_params, api_key)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 63
#      55 conn_params = {
#      56     'host': '3.25.115.34',
#      57     'port': '5432',
#    (...)
#      60     'password': 'root'  # 请替换为你的数据库密码
#      61 }
#      62 api_key = 'AIzaSyA4bcHQArQWH2Qxb47goCAhbstZX0WkUZk'
# ---> 63 update_database(conn_params, api_key)
#
# Cell In[7], line 46, in update_database(conn_params, api_key)
#      43 rows = cur.fetchall()
#      45 for row in rows:
# ---> 46     data = query_google_places(row[1], row[2], api_key)
#      47     if data and data['photo_filename']:
#      48         # 更新数据库
#      49         cur.execute("UPDATE public.eatery_drink_data SET rating = %s, description = %s, photo_filename = %s WHERE id = %s",
#      50                     (data['rating'], data['description'], data['photo_filename'], row[0]))
#
# ...

# %%
import requests
import psycopg2
import os

def download_image(image_url, local_filename, save_directory):
    """Download an image and save it to the specified directory."""
    try:
        if not os.path.exists(save_directory):
            os.makedirs(save_directory)
        full_path = os.path.join(save_directory, local_filename)
        
        response = requests.get(image_url)
        if response.status_code == 200:
            with open(full_path, 'wb') as f:
                f.write(response.content)
            return local_filename
        else:
            print(f"Failed to download image. Status code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading the image: {e}")
    return None

def query_google_places(restaurant_name, address, api_key):
    """Query Google Places API to retrieve place details and photo."""
    try:
        search_url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={restaurant_name} {address}&inputtype=textquery&fields=place_id&key={api_key}"
        response = requests.get(search_url)
        search_results = response.json()

        if search_results['status'] == 'OK':
            place_id = search_results['candidates'][0]['place_id']
            details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=name,rating,photo,formatted_address,description&key={api_key}"
            response = requests.get(details_url)
            details = response.json()

            if details['status'] == 'OK':
                result = details['result']
                if 'photos' in result:
                    photo_reference = result['photos'][0]['photo_reference']
                    photo_url = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photoreference={photo_reference}&key={api_key}"
                    image_filename = download_image(photo_url, f"{place_id}.jpg")
                    return {
                        'rating': result.get('rating', 'No Rating'),
                        'description': result.get('description', 'No Description'),
                        'photo_filename': image_filename
                    }
                else:
                    print("No photos available for this place.")
            else:
                print(f"Details request failed with status: {details['status']}")
        else:
            print(f"Search request failed with status: {search_results['status']}")
    except Exception as e:
        print(f"An error occurred while querying Google Places API: {e}")
    return None


def test_update_without_writing_to_db(conn_params, api_key, image_save_directory):
    """Test fetching data from Google Places API and downloading images without writing to the database."""
    try:
        conn = psycopg2.connect(**conn_params)
        cur = conn.cursor()
        cur.execute("SELECT id, trading_name, street_address FROM public.eatery_drink_data")
        rows = cur.fetchall()
        conn.close()

        if rows:
            row = rows[3]
            print(f"Testing with restaurant: ID {row[0]}, Name {row[1]}, Address {row[2]}")
            data = query_google_places(row[1], row[2], api_key)
            if data:
                print(f"Data retrieved: {data}")
                image_filename = download_image(data['photo_url'], f"{row[0].replace(' ', '_')}_image.jpg", image_save_directory)
                print(f"Image downloaded and saved as: {image_filename}")
            else:
                print("No data retrieved from Google Places API.")
        else:
            print("No data found in the database.")
    except psycopg2.DatabaseError as e:
        print(f"Database error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    conn_params = {
        'host': '3.25.115.34',
        'port': '5432',
        'database': 'Static_data',
        'user': 'postgres',
        'password': 'root'
    }
    api_key = 'AIzaSyA4bcHQArQWH2Qxb47goCAhbstZX0WkUZk'
    image_save_directory = '/image'  # Make sure this directory exists and is writable
    test_update_without_writing_to_db(conn_params, api_key, image_save_directory)
# Out:
# Testing with restaurant: ID 4, Name North Star Hotel, Address 218-224 Abbotsford Street NORTH MELBOURNE VIC 3051
# Details request failed with status: INVALID_REQUEST
# No data retrieved from Google Places API.

# %%
import requests

def find_place(input_text, api_key):
    base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
    params = {
        "input": input_text,
        "inputtype": "textquery",
        "fields": "place_id,name,formatted_address",
        "key": api_key
    }

    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        return response.status_code, response.text

# 使用函数
api_key = 'AIzaSyBoLkW6O9ol1GFkd55Pds8wMQEju47FI2A'  # 请确保使用自己的API密钥
input_text = "GT Internet Game Club 71-73 A'Beckett Street MELBOURNE VIC 3000"
place_info = find_place(input_text, api_key)
print(place_info)
# Out:
# {'candidates': [{'formatted_address': "71-73 A'Beckett St, Melbourne VIC 3000, Australia", 'name': "71-73 A'Beckett St", 'place_id': 'ChIJ7_kaLstC1moREJB1Tk_Sh0U'}], 'status': 'OK'}

# %%
import requests
import os

def download_image(image_url, local_filename, save_directory):
    """Download an image and save it to the specified directory."""
    try:
        if not os.path.exists(save_directory):
            os.makedirs(save_directory)
        full_path = os.path.join(save_directory, local_filename)
        
        response = requests.get(image_url)
        if response.status_code == 200:
            with open(full_path, 'wb') as f:
                f.write(response.content)
            return local_filename
        else:
            print(f"Failed to download image. Status code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading the image: {e}")
    return None

def query_google_places(input_text, api_key, image_save_directory):
    """Query Google Places API to retrieve place details and photo."""
    base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
    params = {
        "input": input_text,
        "inputtype": "textquery",
        "fields": "place_id,name,formatted_address",
        "key": api_key
    }
    response = requests.get(base_url, params=params)
    if response.status_code != 200:
        print(f"Search request failed with status1: {response.status_code}")
        return None

    search_results = response.json()
    if search_results['status'] != 'OK':
        print(f"Search request failed with status2: {search_results['status']}")
        return None

    place_id = search_results['candidates'][0]['place_id']
    details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=name,rating,photo,formatted_address,description&key={api_key}"
    response = requests.get(details_url)
    details = response.json()

    if details['status'] != 'OK':
        print(f"Details request failed with status3: {details['status']}")
        return None

    result = details['result']
    if 'photos' in result:
        photo_reference = result['photos'][0]['photo_reference']
        photo_url = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photoreference={photo_reference}&key={api_key}"
        image_filename = download_image(photo_url, f"{place_id}.jpg", image_save_directory)
        return {
            'name': result.get('name'),
            'rating': result.get('rating', 'No Rating'),
            'description': result.get('description', 'No Description'),
            'photo_filename': image_filename
        }
    else:
        print("No photos available for this place.")
    return None

# 使用函数
api_key = 'AIzaSyBoLkW6O9ol1GFkd55Pds8wMQEju47FI2A'
input_text = "Abbot's Seafood 253 Abbotsford Street NORTH MELBOURNE VIC 3051"
image_save_directory = '/image'  # Make sure this directory exists and is writable
place_info = query_google_places(input_text, api_key, image_save_directory)
print(place_info)
# Out:
# Details request failed with status3: INVALID_REQUEST
# None

# %%
https://maps.googleapis.com/maps/api/place/details/json
  # ?fields=name%2Crating%2Cphoto%2Cwebsite%2Cformatted_address
  &place_id=ChIJ7_kaLstC1moREJB1Tk_Sh0U
  &key=AIzaSyBoLkW6O9ol1GFkd55Pds8wMQEju47FI2A

# %%
import requests
import os

def download_image_from_google(photo_reference, api_key, local_filename, save_directory):
    """Download an image from Google Places API using the photo reference."""
    try:
        if not os.path.exists(save_directory):
            os.makedirs(save_directory)
        full_path = os.path.join(save_directory, local_filename)
        
        photo_url = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photoreference={photo_reference}&key={api_key}"
        response = requests.get(photo_url)
        if response.status_code == 200:
            with open(full_path, 'wb') as f:
                f.write(response.content)
            return local_filename
        else:
            print(f"Failed to download image. Status code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading the image: {e}")
    return None

# 使用函数下载图片
api_key = 'AIzaSyBoLkW6O9ol1GFkd55Pds8wMQEju47FI2A'  # 替换成你的API密钥
photo_reference = "ATplDJY3dxkfuWMSkFDIxLUQcYhBjoPqejl9c07sDnLDaOBkeD9GUSD3dWrzWB4fhuxMO0lnlGNBpxwo8GLnCHsW1R0gBDnJZLmYzshJNpD5mom4b963vohOhKUWHPQZuCuhF7EANALcxxsa8MJ3-N_T9bcEEo6w_-dHxNHjcCvCFgUIwBI"
local_filename = "downloaded_image.jpg"
save_directory = 'image'  # 确保此目录存在且你有写入权限

downloaded_image = download_image_from_google(photo_reference, api_key, local_filename, save_directory)
if downloaded_image:
    print(f"Image downloaded and saved as: {downloaded_image}")
else:
    print("Failed to download the image.")
# Out:
# Image downloaded and saved as: downloaded_image.jpg

# %%
# Divia

# %%
import psycopg2
import requests
import os
import csv
api_key = 'AIzaSyDjQXyYlP5QOFLFJ58xocind5smlnaC3mA'  # 替换成你的API密钥
# Database connection setup
conn_params = {
    'host': '3.25.115.34',
    'port': '5432',
    'database': 'Static_data',
    'user': 'postgres',
    'password': 'root'  # Replace with your actual password
}

def download_image_from_google(photo_reference, api_key, local_filename, save_directory):
    """Download an image from Google Places API using the photo reference."""
    try:
        if not os.path.exists(save_directory):
            os.makedirs(save_directory)
        full_path = os.path.join(save_directory, local_filename)
        
        photo_url = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photoreference={photo_reference}&key={api_key}"
        response = requests.get(photo_url)
        if response.status_code == 200:
            with open(full_path, 'wb') as f:
                f.write(response.content)
            return local_filename
        else:
            print(f"Failed to download image. Status code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading the image: {e}")
    return None

def find_place(input_text, api_key):
    """Query Google Places API for a place ID based on the input text."""
    base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
    params = {
        "input": input_text,
        "inputtype": "textquery",
        "fields": "place_id,name,formatted_address",
        "key": api_key
    }
    response = requests.get(base_url, params=params)
    print(f"Finding place for: {input_text}")
    if response.status_code == 200:
        result = response.json()
        print(f"Find place result: {result}")
        return result
    else:
        print(f"Error finding place: {response.status_code} {response.text}")
        return None

def query_place_details(place_id, api_key):
    """Query Google Places API for place details."""
    url = f"https://maps.googleapis.com/maps/api/place/details/json?fields=name%2Crating%2Cphoto%2Cwebsite%2Cformatted_address&place_id={place_id}&key={api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    return response.status_code, response.text

def save_to_csv(row_data, filename):
    """Save data to a CSV file."""
    with open(filename, 'a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(row_data)

def main(api_key, save_directory, csv_filename):
    try:
        # Connect to the database
        conn = psycopg2.connect(**conn_params)
        cur = conn.cursor()
        cur.execute("SELECT id, street_address FROM public.retail_data")

        # Clear existing data in CSV (optional, uncomment next line to enable)
        # open(csv_filename, 'w').close()

        # Process each row
        for row in cur.fetchall():
            input_text = f"{row[1]}"
            place_info = find_place(input_text, api_key)
            if place_info and place_info['status'] == 'OK' and 'candidates' in place_info:
                place_id = place_info['candidates'][0]['place_id']
                details = query_place_details(place_id, api_key)
                if details and 'result' in details and 'photos' in details['result']:
                    result = details['result']
                    photo_reference = result['photos'][0]['photo_reference']
                    local_filename = f"{row[0]}.jpg"
                    photo_filename = download_image_from_google(photo_reference, api_key, local_filename, save_directory)
                    if photo_filename:
                        data_row = [row[0], result['name'], result.get('rating', 'No Rating'), result.get('website', 'No Website'), result['formatted_address'], photo_filename]
                        save_to_csv(data_row, csv_filename)
                        print(f"Data for {row[1]} saved with image {photo_filename}")
    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        if conn:
            conn.close()

# Usage
api_key = 'AIzaSyDjQXyYlP5QOFLFJ58xocind5smlnaC3mA'
save_directory = 'image'  # Ensure this directory exists and you have write access
csv_filename = 'data_file.csv'  # Path

if __name__ == "__main__":
    main(api_key, save_directory, csv_filename)
# Out:
# Finding place for: 0 Campbell Arcade MELBOURNE 3000
# Find place result: {'candidates': [{'formatted_address': '248 Flinders St, Melbourne VIC 3000, Australia', 'name': 'Campbell Arcade (Underground)', 'place_id': 'ChIJic_UGrRC1moRng7Vv3U2Esg'}], 'status': 'OK'}
# Data for 0 Campbell Arcade MELBOURNE 3000 saved with image 1.jpg
# Finding place for: 0 Flinders Street MELBOURNE 3000
# Find place result: {'candidates': [{'formatted_address': '0 Flinders St, East Melbourne VIC 3000, Australia', 'name': '0 Flinders St', 'place_id': 'EjEwIEZsaW5kZXJzIFN0LCBFYXN0IE1lbGJvdXJuZSBWSUMgMzAwMCwgQXVzdHJhbGlhIjASLgoUChIJP48GmcdC1moRcmsn0BKEvY8QACoUChIJSZM-DbNC1moRanEDWTL9q_s'}], 'status': 'OK'}
# Finding place for: 1 Gower Street KENSINGTON 3031
# Find place result: {'candidates': [{'formatted_address': '1 Gower St, Kensington VIC 3031, Australia', 'name': '1 Gower St', 'place_id': 'ChIJNzOKsRFd1moR9OWpTs3bMLo'}], 'status': 'OK'}
# Finding place for: 1 West Gate Freeway FISHERMANS BEND 3207
# ...

# %%
import psycopg2
import requests
import csv

# Database connection setup
conn_params = {
    'host': '3.25.115.34',
    'port': '5432',
    'database': 'Static_data',
    'user': 'postgres',
    'password': 'root'  # Replace with your actual password
}

def find_place(input_text, api_key):
    """Query Google Places API for a place ID based on the input text."""
    base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
    params = {
        "input": input_text,
        "inputtype": "textquery",
        "fields": "place_id",
        "key": api_key
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        result = response.json()
        if result['status'] == 'OK' and result['candidates']:
            return result['candidates'][0]['place_id']
    return None

def query_place_details(place_id, api_key):
    """Query Google Places API for user ratings total."""
    url = f"https://maps.googleapis.com/maps/api/place/details/json?fields=user_ratings_total&place_id={place_id}&key={api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        details = response.json()
        if 'result' in details and 'user_ratings_total' in details['result']:
            return details['result']['user_ratings_total']
    return 0  # Return 0 if no user ratings found or an error occurred

def save_to_csv(row_data, filename):
    """Save data to a CSV file."""
    with open(filename, 'a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(row_data)

def main(api_key, csv_filename):
    try:
        # Connect to the database
        conn = psycopg2.connect(**conn_params)
        cur = conn.cursor()
        cur.execute("SELECT id, format_name, format_address FROM public.eatery_drink_api_data WHERE format_name IS NOT NULL;")

        # Clear existing data in CSV (optional, uncomment next line to enable)
        # open(csv_filename, 'w').close()

        # Process each row
        for row in cur.fetchall():
            input_text = f"{row[1]} {row[2]}"
            place_id = find_place(input_text, api_key)
            if place_id:
                user_ratings_total = query_place_details(place_id, api_key)
                data_row = [row[0], user_ratings_total]
                save_to_csv(data_row, csv_filename)
                print(f"Data saved for {row[1]}: Database ID {row[0]}, User Ratings Total {user_ratings_total}")
    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        if conn:
            conn.close()

# Usage
api_key = 'AIzaSyBoLkW6O9ol1GFkd55Pds8wMQEju47FI2A'  # Replace with your actual Google API key
csv_filename = 'data_file_2.csv'  # Path to CSV file

if __name__ == "__main__":
    main(api_key, csv_filename)
# Out:
# Data saved for None: Database ID 2, User Ratings Total 186
# Data saved for None: Database ID 9, User Ratings Total 186
# Data saved for None: Database ID 74, User Ratings Total 186
# Data saved for None: Database ID 10, User Ratings Total 186
# Data saved for None: Database ID 11, User Ratings Total 186
# Data saved for None: Database ID 12, User Ratings Total 186
# Data saved for None: Database ID 377, User Ratings Total 186
# Data saved for None: Database ID 270, User Ratings Total 186
# Data saved for None: Database ID 427, User Ratings Total 186
# Data saved for None: Database ID 476, User Ratings Total 186
# Data saved for None: Database ID 552, User Ratings Total 186
# Data saved for None: Database ID 573, User Ratings Total 186
# Data saved for None: Database ID 605, User Ratings Total 186
# Data saved for Bluebag Fresh: Database ID 192, User Ratings Total 121
# Data saved for Albert Street Deli: Database ID 13, User Ratings Total 7
# ...

# %%
import requests
import datetime
import time

# 起点和终点地址
origin = "1600 Amphitheatre Parkway, Mountain View, CA"
destination = "1 Infinite Loop, Cupertino, CA"
api_key = "AIzaSyDjQXyYlP5QOFLFJ58xocind5smlnaC3mA"  # 替换成你的Google Maps API 密钥

# 计算出发时间（当前时间）
departure_time = int(time.time())


# 构建请求URL
url = (
    f"https://maps.googleapis.com/maps/api/directions/json?"
    f"origin={origin}&destination={destination}&mode=transit&"
    f"departure_time={departure_time}&key={api_key}"
)

# 发送GET请求
response = requests.get(url)

# 检查响应状态码
if response.status_code == 200:
    data = response.json()  # 解析JSON数据
    if data['status'] == 'OK':
        # 提取并打印路线信息
        routes = data['routes']
        print(routes)
    else:
        print("获取路线信息失败:", data['status'])
else:
    print("请求失败，HTTP 状态码：", response.status_code)
    print("错误详情：", response.text)  # 打印出错误信息
# Out:
# [{'bounds': {'northeast': {'lat': 37.4238426, 'lng': -122.0307218}, 'southwest': {'lat': 37.3296697, 'lng': -122.114163}}, 'copyrights': 'Map data ©2024 Google', 'fare': {'currency': 'USD', 'text': '$7.50', 'value': 7.5}, 'legs': [{'arrival_time': {'text': '7:35\u202fAM', 'time_zone': 'America/Los_Angeles', 'value': 1715006107}, 'departure_time': {'text': '6:16\u202fAM', 'time_zone': 'America/Los_Angeles', 'value': 1715001391}, 'distance': {'text': '11.6 mi', 'value': 18649}, 'duration': {'text': '1 hour 19 mins', 'value': 4716}, 'end_address': 'Infinite Loop 1, 1 Infinite Loop, Cupertino, CA 95014, USA', 'end_location': {'lat': 37.3314216, 'lng': -122.0307218}, 'start_address': '1600 Amphitheatre Pkwy, Mountain View, CA 94043, USA', 'start_location': {'lat': 37.4221003, 'lng': -122.0843297}, 'steps': [{'distance': {'text': '0.3 mi', 'value': 434}, 'duration': {'text': '6 mins', 'value': 342}, 'end_location': {'lat': 37.4212825, 'lng': -122.0878567}, 'html_instructions': 'Walk to 195
# ...
